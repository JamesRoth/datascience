# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-89e6c98d9288> in <module>()
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
a

# %%
:j

# %% [markdown]
# :k

# %% [markdown]
# # Ballistics and the Range Equation
# This is an investigation of the so-called *range equation*: $d=\frac {v^2} g  \sin 2\theta$.

# %%
from math import radians, sin, pi
from numpy import linspace
import matplotlib.pyplot as plt

# %%
def rangeformula(v, theta):
    return (v**2)/9.81*sin(2*theta)

# %%
rangeformula(100, 45)
# Out:
# 911.3115836906808

# %%
rangeformula(100,45)

# %%
angledegrees = linspace(0,90, num=200)
rangeforangle100 = [rangeformula(100, radians(angle)) for angle in angledegrees]
rangeforangle200 = [rangeformula(200, radians(angle)) for angle in angledegrees]

# %%
plt.plot(angledegrees, rangeforangle100, label="100m/s")
plt.legend()
plt.plot(angledegrees, rangeforangle200, label="200m/s")
plt.legend()
plt.title('Range as a function of angle at various velocities')
plt.xlabel('Angle (degrees)')
plt.ylabel('Range (meters)')
plt.show()

# %%
from math import radians, sin, pi
from numpy import linspace
angleradians = linspace(0,radians(90),num=200)
rangeforradiansangle100 = [rangeformula(100, angle) for angle in angleradians]
rangeforradiansangle200 = [rangeformula(200, angle) for angle in angleradians]
plt.plot(angleradians, rangeforradiansangle100, label="100m/s")
plt.legend
plt.plot(angleradians, rangeforradiansangle200, label="200m/s")
plt.legend
plt.title('Range as a function of angle in radians at various velocities')
plt.xlabel('Angle (radians)')
plt.ylabel('Range (meters)')
plt.show()

# %%
from math import radians, sin, pi
from numpy import linspace
angle = radians(45)
velocity = linspace(0,200, num=400)
rangeforangle45 = [rangeformula(v, angle) for v in velocity]
plt.plot(velocity, rangeforangle45, label="45 degrees")
plt.legend()
plt.title('Range of a projectile at 45 degrees at various velocities.')
plt.xlabel('Velocity')
plt.ylabel('Range (meters)')
plt.show()

# %%
from math import radians, sin, pi
from numpy import linspace
import matplotlib.pyplot as plt
velocity = linspace(0,200, num=400)
rangeforangle15 = [rangeformula(v, radians(15)) for v in velocity]
rangeforangle30 = [rangeformula(v, radians(30)) for v in velocity]
rangeforangle45 = [rangeformula(v, radians(45)) for v in velocity]
rangeforangle60 = [rangeformula(v, radians(60)) for v in velocity]
rangeforangle75 = [rangeformula(v, radians(75)) for v in velocity]
plt.plot(velocity, rangeforangle15, label="15 degrees")
plt.legend()
plt.plot(velocity, rangeforangle30, label="30 degrees")
plt.legend()
plt.plot(velocity, rangeforangle45, label="45 degrees")
plt.legend()
plt.plot(velocity, rangeforangle60, label="60 degrees")
plt.legend()
plt.plot(velocity, rangeforangle75, label="75 degrees")
plt.legend()
plt.title('Range of a projectile at various degrees bn          at various velocities.')
plt.xlabel('Velocity')
plt.ylabel('Range (meters)')
plt.show()

# %% [markdown]
# # Pros and Cons of Jupyter Notebooks vs. Spreadsheets
#
# **Pros of using Jupyter:**
# * You know that the data is being generated from the equation you entered, as you can see the underlying code
# * You will get an error code if something important has broken
# * You can easily update the formula/number used to compute
# * You can see if anyone has changed anything by looking at the code
#
# **Pros of using Google Sheets:**
# * It is easy to use and does not require any coding experience
# * The chart has more options/settings to change its appearance
# * It can be shared easily and takes less time to create
